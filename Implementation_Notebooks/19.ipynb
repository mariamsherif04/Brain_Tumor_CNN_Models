# %% [markdown]
# ## **Model 19 : ResNet50 (frozen base, train classifier head)**

# %% [markdown]
# **IMG_SIZE → (224, 224) (instead of (128,128)) because MobileNetV2, ResNet50, EfficientNetB0 all expect (224,224,3) input.**

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.applications import MobileNetV2

# Use 224x224 for transfer learning
IMG_SIZE = (224, 224)
BATCH_SIZE = 16
SEED = 42

train_dir = "datasets/Training"
test_dir  = "datasets/Testing"

# Load datasets first (raw, no normalization yet)
raw_train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)

raw_test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels="inferred",
    label_mode="int",
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# Save class names before mapping
class_names = raw_train_ds.class_names
NUM_CLASSES = len(class_names)
print("Classes:", class_names)

# Now split validation
val_size = int(0.2 * len(raw_train_ds))
val_ds = raw_train_ds.take(val_size)
train_ds = raw_train_ds.skip(val_size)

# Normalize
normalization_layer = layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x,y: (normalization_layer(x), y))
val_ds   = val_ds.map(lambda x,y: (normalization_layer(x), y))
test_ds  = raw_test_ds.map(lambda x,y: (normalization_layer(x), y))

# Prefetch
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(AUTOTUNE)
val_ds   = val_ds.cache().prefetch(AUTOTUNE)
test_ds  = test_ds.cache().prefetch(AUTOTUNE)
# Out:
# Found 5712 files belonging to 4 classes.
# Found 1311 files belonging to 4 classes.
# Classes: ['glioma', 'meningioma', 'notumor', 'pituitary']

# %% [markdown]
# **Number of classes = inferred automatically from dataset**

# %%
NUM_CLASSES = len(class_names)

# %% [markdown]
# **Load ResNet50 and build model**

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model

# Load ResNet50 base, without the top classifier
base_model = ResNet50(
    include_top=False,
    weights="imagenet",
    input_shape=(224, 224, 3)
)

# Freeze the base model
base_model.trainable = False

# Add custom classifier head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.5)(x)
predictions = Dense(NUM_CLASSES, activation="softmax")(x)

# Build final model
model19 = Model(inputs=base_model.input, outputs=predictions)

# Compile
model19.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss="sparse_categorical_crossentropy",  # since labels are integers
    metrics=["accuracy"]
)

# %% [markdown]
# **Callbacks**

# %%
callbacks = [
    EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6),
    ModelCheckpoint("models/model19_best.keras", monitor="val_loss", save_best_only=True)
]

# %% [markdown]
# **Train**

# %%
history19 = model19.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=callbacks
)
# Out:
# Epoch 1/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 176s 597ms/step - accuracy: 0.3000 - loss: 1.7243 - val_accuracy: 0.4454 - val_loss: 1.2559 - learning_rate: 1.0000e-04
# Epoch 2/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 583ms/step - accuracy: 0.3433 - loss: 1.4177 - val_accuracy: 0.4120 - val_loss: 1.2227 - learning_rate: 1.0000e-04
# Epoch 3/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 583ms/step - accuracy: 0.3680 - loss: 1.3188 - val_accuracy: 0.6100 - val_loss: 1.2098 - learning_rate: 1.0000e-04
# Epoch 4/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 584ms/step - accuracy: 0.4014 - loss: 1.2629 - val_accuracy: 0.4842 - val_loss: 1.1926 - learning_rate: 1.0000e-04
# Epoch 5/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 166s 581ms/step - accuracy: 0.4218 - loss: 1.2265 - val_accuracy: 0.4965 - val_loss: 1.1767 - learning_rate: 1.0000e-04
# Epoch 6/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 584ms/step - accuracy: 0.4207 - loss: 1.2124 - val_accuracy: 0.5202 - val_loss: 1.1668 - learning_rate: 1.0000e-04
# Epoch 7/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 584ms/step - accuracy: 0.4373 - loss: 1.1896 - val_accuracy: 0.5088 - val_loss: 1.1442 - learning_rate: 1.0000e-04
# Epoch 8/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 164s 575ms/step - accuracy: 0.4451 - loss: 1.1821 - val_accuracy: 0.4798 - val_loss: 1.1333 - learning_rate: 1.0000e-04
# Epoch 9/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 163s 572ms/step - accuracy: 0.4600 - loss: 1.1569 - val_accuracy: 0.6109 - val_loss: 1.1058 - learning_rate: 1.0000e-04
# Epoch 10/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 166s 580ms/step - accuracy: 0.4709 - loss: 1.1518 - val_accuracy: 0.5739 - val_loss: 1.1061 - learning_rate: 1.0000e-04
# Epoch 11/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 584ms/step - accuracy: 0.4819 - loss: 1.1290 - val_accuracy: 0.5088 - val_loss: 1.0869 - learning_rate: 1.0000e-04
# Epoch 12/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 168s 586ms/step - accuracy: 0.4967 - loss: 1.1172 - val_accuracy: 0.5246 - val_loss: 1.0682 - learning_rate: 1.0000e-04
# Epoch 13/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 170s 593ms/step - accuracy: 0.4985 - loss: 1.1041 - val_accuracy: 0.5581 - val_loss: 1.0585 - learning_rate: 1.0000e-04
# Epoch 14/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 585ms/step - accuracy: 0.5081 - loss: 1.1001 - val_accuracy: 0.5651 - val_loss: 1.0426 - learning_rate: 1.0000e-04
# Epoch 15/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 586ms/step - accuracy: 0.5103 - loss: 1.0917 - val_accuracy: 0.6215 - val_loss: 1.0189 - learning_rate: 1.0000e-04
# Epoch 16/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 168s 588ms/step - accuracy: 0.5160 - loss: 1.0791 - val_accuracy: 0.6004 - val_loss: 1.0107 - learning_rate: 1.0000e-04
# Epoch 17/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 169s 590ms/step - accuracy: 0.5337 - loss: 1.0638 - val_accuracy: 0.6021 - val_loss: 1.0031 - learning_rate: 1.0000e-04
# Epoch 18/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 586ms/step - accuracy: 0.5354 - loss: 1.0554 - val_accuracy: 0.6039 - val_loss: 0.9939 - learning_rate: 1.0000e-04
# Epoch 19/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 585ms/step - accuracy: 0.5389 - loss: 1.0508 - val_accuracy: 0.6030 - val_loss: 0.9835 - learning_rate: 1.0000e-04
# Epoch 20/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 585ms/step - accuracy: 0.5555 - loss: 1.0310 - val_accuracy: 0.6171 - val_loss: 0.9748 - learning_rate: 1.0000e-04
# Epoch 21/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 585ms/step - accuracy: 0.5570 - loss: 1.0338 - val_accuracy: 0.6452 - val_loss: 0.9481 - learning_rate: 1.0000e-04
# Epoch 22/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 163s 569ms/step - accuracy: 0.5579 - loss: 1.0286 - val_accuracy: 0.6153 - val_loss: 0.9505 - learning_rate: 1.0000e-04
# Epoch 23/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 162s 567ms/step - accuracy: 0.5618 - loss: 1.0218 - val_accuracy: 0.6109 - val_loss: 0.9475 - learning_rate: 1.0000e-04
# Epoch 24/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 162s 567ms/step - accuracy: 0.5675 - loss: 1.0069 - val_accuracy: 0.6136 - val_loss: 0.9373 - learning_rate: 1.0000e-04
# Epoch 25/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 165s 579ms/step - accuracy: 0.5645 - loss: 1.0083 - val_accuracy: 0.6294 - val_loss: 0.9281 - learning_rate: 1.0000e-04
# Epoch 26/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 172s 603ms/step - accuracy: 0.5686 - loss: 0.9971 - val_accuracy: 0.6488 - val_loss: 0.9168 - learning_rate: 1.0000e-04
# Epoch 27/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 165s 578ms/step - accuracy: 0.5793 - loss: 0.9899 - val_accuracy: 0.6109 - val_loss: 0.9269 - learning_rate: 1.0000e-04
# Epoch 28/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 585ms/step - accuracy: 0.5889 - loss: 0.9826 - val_accuracy: 0.6435 - val_loss: 0.9004 - learning_rate: 1.0000e-04
# Epoch 29/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 166s 579ms/step - accuracy: 0.5881 - loss: 0.9758 - val_accuracy: 0.6224 - val_loss: 0.9115 - learning_rate: 1.0000e-04
# Epoch 30/30
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 167s 585ms/step - accuracy: 0.5841 - loss: 0.9752 - val_accuracy: 0.6620 - val_loss: 0.8836 - learning_rate: 1.0000e-04

# %% [markdown]
# **Best model**

# %%
best_model19 = tf.keras.models.load_model("models/model19_best.keras")

# %% [markdown]
# **Evaluate**

# %%
from eval import evaluate_model
# Evaluate Model 19
evaluate_model(model19, history19,
                test_ds, "ResNet50 (frozen base, train classifier head)")
# Out:
# ResNet50 (frozen base, train classifier head) - Test accuracy: 0.6110
# ResNet50 (frozen base, train classifier head) - Test loss: 0.9856
# ResNet50 (frozen base, train classifier head) - Final training accuracy: 0.5841
# ResNet50 (frozen base, train classifier head) - Final training loss: 0.9752
# ResNet50 (frozen base, train classifier head) - Final validation accuracy: 0.6620
# ResNet50 (frozen base, train classifier head) - Final validation loss: 0.8836

# %% [markdown]
# **Plot**

# %%
from plot_utils import plot_training_curves
plot_training_curves(history19, 
                     model_name="MobileNetV2 - Fine-tune last 20 (Model 19)")

# %%
from plot_utils import (
    plot_training_curves,
    evaluate_model_with_confusion,
    plot_confusion_matrix_from_dataset
)

class_names = ['glioma', 'meningioma', 'notumor', 'pituitary']

# Confusion matrix with in-memory model
# evaluate_model_with_confusion(model19, test_ds, title="Confusion Matrix (Test)")

# Confusion matrix from saved model
plot_confusion_matrix_from_dataset("models/model19_best.keras", test_ds, class_names)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       glioma       0.69      0.39      0.50       300
#   meningioma       0.49      0.35      0.41       306
#      notumor       0.80      0.72      0.76       405
#    pituitary       0.51      0.95      0.66       300
#
#     accuracy                           0.61      1311
#    macro avg       0.62      0.60      0.58      1311
# weighted avg       0.64      0.61      0.60      1311
